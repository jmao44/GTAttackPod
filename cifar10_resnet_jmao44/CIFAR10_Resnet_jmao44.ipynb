# %% [markdown]
# ## Training 2 new ResNet models on CIFAR-10 dataset

# %%
# imports
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# %%
import tensorflow as tf
if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device: /device:GPU:0

# %%
# Training parameters
batch_size = 32  # orig paper trained all networks with batch_size=128
epochs = 150
data_augmentation = True
num_classes = 10
# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# adjusting layers
n = 12
version = 2
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2
model_type = 'ResNet%dv%d' % (depth, version)

# %%
# load CIFAR-10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
input_shape = x_train.shape[1:]

# normalize data
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(lr=lr_schedule(0)),
    metrics=['accuracy']
)

model.summary()
print(model_type)

save_dir = '../models/weights/'
model_name = 'CIFAR10_%s.keras_weights.h5' % model_type
filepath = os.path.join(save_dir, model_name)

checkpoint = ModelCheckpoint(
    filepath=filepath,
    monitor='val_acc',
    verbose=1,
    save_best_only=True
)

lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(
    factor=np.sqrt(0.1),
    cooldown=0,
    patience=5,
    min_lr=0.5e-6
)

callbacks = [checkpoint, lr_reducer, lr_scheduler]
# Out:
# Learning rate:  0.001
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_247 (Conv2D)             (None, 32, 32, 16)   448         input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_238 (BatchN (None, 32, 32, 16)   64          conv2d_247[0][0]
# __________________________________________________________________________________________________
# activation_238 (Activation)     (None, 32, 32, 16)   0           batch_normalization_238[0][0]
# __________________________________________________________________________________________________
# conv2d_248 (Conv2D)             (None, 32, 32, 16)   272         activation_238[0][0]
# __________________________________________________________________________________________________
# batch_normalization_239 (BatchN (None, 32, 32, 16)   64          conv2d_248[0][0]
# __________________________________________________________________________________________________
# activation_239 (Activation)     (None, 32, 32, 16)   0           batch_normalization_239[0][0]
# __________________________________________________________________________________________________
# conv2d_249 (Conv2D)             (None, 32, 32, 16)   2320        activation_239[0][0]
# __________________________________________________________________________________________________
# batch_normalization_240 (BatchN (None, 32, 32, 16)   64          conv2d_249[0][0]
# __________________________________________________________________________________________________
# activation_240 (Activation)     (None, 32, 32, 16)   0           batch_normalization_240[0][0]
# __________________________________________________________________________________________________
# conv2d_251 (Conv2D)             (None, 32, 32, 64)   1088        activation_238[0][0]
# __________________________________________________________________________________________________
# conv2d_250 (Conv2D)             (None, 32, 32, 64)   1088        activation_240[0][0]
# __________________________________________________________________________________________________
# add_79 (Add)                    (None, 32, 32, 64)   0           conv2d_251[0][0]
#                                                                  conv2d_250[0][0]
# __________________________________________________________________________________________________
# batch_normalization_241 (BatchN (None, 32, 32, 64)   256         add_79[0][0]
# __________________________________________________________________________________________________
# activation_241 (Activation)     (None, 32, 32, 64)   0           batch_normalization_241[0][0]
# __________________________________________________________________________________________________
# conv2d_252 (Conv2D)             (None, 32, 32, 16)   1040        activation_241[0][0]
# __________________________________________________________________________________________________
# batch_normalization_242 (BatchN (None, 32, 32, 16)   64          conv2d_252[0][0]
# __________________________________________________________________________________________________
# activation_242 (Activation)     (None, 32, 32, 16)   0           batch_normalization_242[0][0]
# __________________________________________________________________________________________________
# conv2d_253 (Conv2D)             (None, 32, 32, 16)   2320        activation_242[0][0]
# __________________________________________________________________________________________________
# batch_normalization_243 (BatchN (None, 32, 32, 16)   64          conv2d_253[0][0]
# __________________________________________________________________________________________________
# activation_243 (Activation)     (None, 32, 32, 16)   0           batch_normalization_243[0][0]
# __________________________________________________________________________________________________
# conv2d_254 (Conv2D)             (None, 32, 32, 64)   1088        activation_243[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, 32, 32, 64)   0           add_79[0][0]
#                                                                  conv2d_254[0][0]
# __________________________________________________________________________________________________
# batch_normalization_244 (BatchN (None, 32, 32, 64)   256         add_80[0][0]
# __________________________________________________________________________________________________
# activation_244 (Activation)     (None, 32, 32, 64)   0           batch_normalization_244[0][0]
# __________________________________________________________________________________________________
# conv2d_255 (Conv2D)             (None, 32, 32, 16)   1040        activation_244[0][0]
# __________________________________________________________________________________________________
# batch_normalization_245 (BatchN (None, 32, 32, 16)   64          conv2d_255[0][0]
# __________________________________________________________________________________________________
# activation_245 (Activation)     (None, 32, 32, 16)   0           batch_normalization_245[0][0]
# __________________________________________________________________________________________________
# conv2d_256 (Conv2D)             (None, 32, 32, 16)   2320        activation_245[0][0]
# __________________________________________________________________________________________________
# batch_normalization_246 (BatchN (None, 32, 32, 16)   64          conv2d_256[0][0]
# __________________________________________________________________________________________________
# activation_246 (Activation)     (None, 32, 32, 16)   0           batch_normalization_246[0][0]
# __________________________________________________________________________________________________
# conv2d_257 (Conv2D)             (None, 32, 32, 64)   1088        activation_246[0][0]
# __________________________________________________________________________________________________
# add_81 (Add)                    (None, 32, 32, 64)   0           add_80[0][0]
#                                                                  conv2d_257[0][0]
# __________________________________________________________________________________________________
# batch_normalization_247 (BatchN (None, 32, 32, 64)   256         add_81[0][0]
# __________________________________________________________________________________________________
# activation_247 (Activation)     (None, 32, 32, 64)   0           batch_normalization_247[0][0]
# __________________________________________________________________________________________________
# conv2d_258 (Conv2D)             (None, 32, 32, 16)   1040        activation_247[0][0]
# __________________________________________________________________________________________________
# batch_normalization_248 (BatchN (None, 32, 32, 16)   64          conv2d_258[0][0]
# __________________________________________________________________________________________________
# activation_248 (Activation)     (None, 32, 32, 16)   0           batch_normalization_248[0][0]
# __________________________________________________________________________________________________
# conv2d_259 (Conv2D)             (None, 32, 32, 16)   2320        activation_248[0][0]
# __________________________________________________________________________________________________
# batch_normalization_249 (BatchN (None, 32, 32, 16)   64          conv2d_259[0][0]
# __________________________________________________________________________________________________
# activation_249 (Activation)     (None, 32, 32, 16)   0           batch_normalization_249[0][0]
# __________________________________________________________________________________________________
# conv2d_260 (Conv2D)             (None, 32, 32, 64)   1088        activation_249[0][0]
# __________________________________________________________________________________________________
# add_82 (Add)                    (None, 32, 32, 64)   0           add_81[0][0]
#                                                                  conv2d_260[0][0]
# __________________________________________________________________________________________________
# batch_normalization_250 (BatchN (None, 32, 32, 64)   256         add_82[0][0]
# __________________________________________________________________________________________________
# activation_250 (Activation)     (None, 32, 32, 64)   0           batch_normalization_250[0][0]
# __________________________________________________________________________________________________
# conv2d_261 (Conv2D)             (None, 32, 32, 16)   1040        activation_250[0][0]
# __________________________________________________________________________________________________
# batch_normalization_251 (BatchN (None, 32, 32, 16)   64          conv2d_261[0][0]
# __________________________________________________________________________________________________
# activation_251 (Activation)     (None, 32, 32, 16)   0           batch_normalization_251[0][0]
# __________________________________________________________________________________________________
# conv2d_262 (Conv2D)             (None, 32, 32, 16)   2320        activation_251[0][0]
# __________________________________________________________________________________________________
# batch_normalization_252 (BatchN (None, 32, 32, 16)   64          conv2d_262[0][0]
# __________________________________________________________________________________________________
# activation_252 (Activation)     (None, 32, 32, 16)   0           batch_normalization_252[0][0]
# __________________________________________________________________________________________________
# conv2d_263 (Conv2D)             (None, 32, 32, 64)   1088        activation_252[0][0]
# __________________________________________________________________________________________________
# add_83 (Add)                    (None, 32, 32, 64)   0           add_82[0][0]
#                                                                  conv2d_263[0][0]
# __________________________________________________________________________________________________
# batch_normalization_253 (BatchN (None, 32, 32, 64)   256         add_83[0][0]
# __________________________________________________________________________________________________
# activation_253 (Activation)     (None, 32, 32, 64)   0           batch_normalization_253[0][0]
# __________________________________________________________________________________________________
# conv2d_264 (Conv2D)             (None, 32, 32, 16)   1040        activation_253[0][0]
# __________________________________________________________________________________________________
# batch_normalization_254 (BatchN (None, 32, 32, 16)   64          conv2d_264[0][0]
# __________________________________________________________________________________________________
# activation_254 (Activation)     (None, 32, 32, 16)   0           batch_normalization_254[0][0]
# __________________________________________________________________________________________________
# conv2d_265 (Conv2D)             (None, 32, 32, 16)   2320        activation_254[0][0]
# __________________________________________________________________________________________________
# batch_normalization_255 (BatchN (None, 32, 32, 16)   64          conv2d_265[0][0]
# __________________________________________________________________________________________________
# activation_255 (Activation)     (None, 32, 32, 16)   0           batch_normalization_255[0][0]
# __________________________________________________________________________________________________
# conv2d_266 (Conv2D)             (None, 32, 32, 64)   1088        activation_255[0][0]
# __________________________________________________________________________________________________
# add_84 (Add)                    (None, 32, 32, 64)   0           add_83[0][0]
#                                                                  conv2d_266[0][0]
# __________________________________________________________________________________________________
# batch_normalization_256 (BatchN (None, 32, 32, 64)   256         add_84[0][0]
# __________________________________________________________________________________________________
# activation_256 (Activation)     (None, 32, 32, 64)   0           batch_normalization_256[0][0]
# __________________________________________________________________________________________________
# conv2d_267 (Conv2D)             (None, 32, 32, 16)   1040        activation_256[0][0]
# __________________________________________________________________________________________________
# batch_normalization_257 (BatchN (None, 32, 32, 16)   64          conv2d_267[0][0]
# __________________________________________________________________________________________________
# activation_257 (Activation)     (None, 32, 32, 16)   0           batch_normalization_257[0][0]
# __________________________________________________________________________________________________
# conv2d_268 (Conv2D)             (None, 32, 32, 16)   2320        activation_257[0][0]
# __________________________________________________________________________________________________
# batch_normalization_258 (BatchN (None, 32, 32, 16)   64          conv2d_268[0][0]
# __________________________________________________________________________________________________
# activation_258 (Activation)     (None, 32, 32, 16)   0           batch_normalization_258[0][0]
# __________________________________________________________________________________________________
# conv2d_269 (Conv2D)             (None, 32, 32, 64)   1088        activation_258[0][0]
# __________________________________________________________________________________________________
# add_85 (Add)                    (None, 32, 32, 64)   0           add_84[0][0]
#                                                                  conv2d_269[0][0]
# __________________________________________________________________________________________________
# batch_normalization_259 (BatchN (None, 32, 32, 64)   256         add_85[0][0]
# __________________________________________________________________________________________________
# activation_259 (Activation)     (None, 32, 32, 64)   0           batch_normalization_259[0][0]
# __________________________________________________________________________________________________
# conv2d_270 (Conv2D)             (None, 32, 32, 16)   1040        activation_259[0][0]
# __________________________________________________________________________________________________
# batch_normalization_260 (BatchN (None, 32, 32, 16)   64          conv2d_270[0][0]
# __________________________________________________________________________________________________
# activation_260 (Activation)     (None, 32, 32, 16)   0           batch_normalization_260[0][0]
# __________________________________________________________________________________________________
# conv2d_271 (Conv2D)             (None, 32, 32, 16)   2320        activation_260[0][0]
# __________________________________________________________________________________________________
# batch_normalization_261 (BatchN (None, 32, 32, 16)   64          conv2d_271[0][0]
# __________________________________________________________________________________________________
# activation_261 (Activation)     (None, 32, 32, 16)   0           batch_normalization_261[0][0]
# __________________________________________________________________________________________________
# conv2d_272 (Conv2D)             (None, 32, 32, 64)   1088        activation_261[0][0]
# __________________________________________________________________________________________________
# add_86 (Add)                    (None, 32, 32, 64)   0           add_85[0][0]
#                                                                  conv2d_272[0][0]
# __________________________________________________________________________________________________
# batch_normalization_262 (BatchN (None, 32, 32, 64)   256         add_86[0][0]
# __________________________________________________________________________________________________
# activation_262 (Activation)     (None, 32, 32, 64)   0           batch_normalization_262[0][0]
# __________________________________________________________________________________________________
# conv2d_273 (Conv2D)             (None, 32, 32, 16)   1040        activation_262[0][0]
# __________________________________________________________________________________________________
# batch_normalization_263 (BatchN (None, 32, 32, 16)   64          conv2d_273[0][0]
# __________________________________________________________________________________________________
# activation_263 (Activation)     (None, 32, 32, 16)   0           batch_normalization_263[0][0]
# __________________________________________________________________________________________________
# conv2d_274 (Conv2D)             (None, 32, 32, 16)   2320        activation_263[0][0]
# __________________________________________________________________________________________________
# batch_normalization_264 (BatchN (None, 32, 32, 16)   64          conv2d_274[0][0]
# __________________________________________________________________________________________________
# activation_264 (Activation)     (None, 32, 32, 16)   0           batch_normalization_264[0][0]
# __________________________________________________________________________________________________
# conv2d_275 (Conv2D)             (None, 32, 32, 64)   1088        activation_264[0][0]
# __________________________________________________________________________________________________
# add_87 (Add)                    (None, 32, 32, 64)   0           add_86[0][0]
#                                                                  conv2d_275[0][0]
# __________________________________________________________________________________________________
# batch_normalization_265 (BatchN (None, 32, 32, 64)   256         add_87[0][0]
# __________________________________________________________________________________________________
# activation_265 (Activation)     (None, 32, 32, 64)   0           batch_normalization_265[0][0]
# __________________________________________________________________________________________________
# conv2d_276 (Conv2D)             (None, 32, 32, 16)   1040        activation_265[0][0]
# __________________________________________________________________________________________________
# batch_normalization_266 (BatchN (None, 32, 32, 16)   64          conv2d_276[0][0]
# __________________________________________________________________________________________________
# activation_266 (Activation)     (None, 32, 32, 16)   0           batch_normalization_266[0][0]
# __________________________________________________________________________________________________
# conv2d_277 (Conv2D)             (None, 32, 32, 16)   2320        activation_266[0][0]
# __________________________________________________________________________________________________
# batch_normalization_267 (BatchN (None, 32, 32, 16)   64          conv2d_277[0][0]
# __________________________________________________________________________________________________
# activation_267 (Activation)     (None, 32, 32, 16)   0           batch_normalization_267[0][0]
# __________________________________________________________________________________________________
# conv2d_278 (Conv2D)             (None, 32, 32, 64)   1088        activation_267[0][0]
# __________________________________________________________________________________________________
# add_88 (Add)                    (None, 32, 32, 64)   0           add_87[0][0]
#                                                                  conv2d_278[0][0]
# __________________________________________________________________________________________________
# batch_normalization_268 (BatchN (None, 32, 32, 64)   256         add_88[0][0]
# __________________________________________________________________________________________________
# activation_268 (Activation)     (None, 32, 32, 64)   0           batch_normalization_268[0][0]
# __________________________________________________________________________________________________
# conv2d_279 (Conv2D)             (None, 32, 32, 16)   1040        activation_268[0][0]
# __________________________________________________________________________________________________
# batch_normalization_269 (BatchN (None, 32, 32, 16)   64          conv2d_279[0][0]
# __________________________________________________________________________________________________
# activation_269 (Activation)     (None, 32, 32, 16)   0           batch_normalization_269[0][0]
# __________________________________________________________________________________________________
# conv2d_280 (Conv2D)             (None, 32, 32, 16)   2320        activation_269[0][0]
# __________________________________________________________________________________________________
# batch_normalization_270 (BatchN (None, 32, 32, 16)   64          conv2d_280[0][0]
# __________________________________________________________________________________________________
# activation_270 (Activation)     (None, 32, 32, 16)   0           batch_normalization_270[0][0]
# __________________________________________________________________________________________________
# conv2d_281 (Conv2D)             (None, 32, 32, 64)   1088        activation_270[0][0]
# __________________________________________________________________________________________________
# add_89 (Add)                    (None, 32, 32, 64)   0           add_88[0][0]
#                                                                  conv2d_281[0][0]
# __________________________________________________________________________________________________
# batch_normalization_271 (BatchN (None, 32, 32, 64)   256         add_89[0][0]
# __________________________________________________________________________________________________
# activation_271 (Activation)     (None, 32, 32, 64)   0           batch_normalization_271[0][0]
# __________________________________________________________________________________________________
# conv2d_282 (Conv2D)             (None, 32, 32, 16)   1040        activation_271[0][0]
# __________________________________________________________________________________________________
# batch_normalization_272 (BatchN (None, 32, 32, 16)   64          conv2d_282[0][0]
# __________________________________________________________________________________________________
# activation_272 (Activation)     (None, 32, 32, 16)   0           batch_normalization_272[0][0]
# __________________________________________________________________________________________________
# conv2d_283 (Conv2D)             (None, 32, 32, 16)   2320        activation_272[0][0]
# __________________________________________________________________________________________________
# batch_normalization_273 (BatchN (None, 32, 32, 16)   64          conv2d_283[0][0]
# __________________________________________________________________________________________________
# activation_273 (Activation)     (None, 32, 32, 16)   0           batch_normalization_273[0][0]
# __________________________________________________________________________________________________
# conv2d_284 (Conv2D)             (None, 32, 32, 64)   1088        activation_273[0][0]
# __________________________________________________________________________________________________
# add_90 (Add)                    (None, 32, 32, 64)   0           add_89[0][0]
#                                                                  conv2d_284[0][0]
# __________________________________________________________________________________________________
# batch_normalization_274 (BatchN (None, 32, 32, 64)   256         add_90[0][0]
# __________________________________________________________________________________________________
# activation_274 (Activation)     (None, 32, 32, 64)   0           batch_normalization_274[0][0]
# __________________________________________________________________________________________________
# conv2d_285 (Conv2D)             (None, 16, 16, 64)   4160        activation_274[0][0]
# __________________________________________________________________________________________________
# batch_normalization_275 (BatchN (None, 16, 16, 64)   256         conv2d_285[0][0]
# __________________________________________________________________________________________________
# activation_275 (Activation)     (None, 16, 16, 64)   0           batch_normalization_275[0][0]
# __________________________________________________________________________________________________
# conv2d_286 (Conv2D)             (None, 16, 16, 64)   36928       activation_275[0][0]
# __________________________________________________________________________________________________
# batch_normalization_276 (BatchN (None, 16, 16, 64)   256         conv2d_286[0][0]
# __________________________________________________________________________________________________
# activation_276 (Activation)     (None, 16, 16, 64)   0           batch_normalization_276[0][0]
# __________________________________________________________________________________________________
# conv2d_288 (Conv2D)             (None, 16, 16, 128)  8320        add_90[0][0]
# __________________________________________________________________________________________________
# conv2d_287 (Conv2D)             (None, 16, 16, 128)  8320        activation_276[0][0]
# __________________________________________________________________________________________________
# add_91 (Add)                    (None, 16, 16, 128)  0           conv2d_288[0][0]
#                                                                  conv2d_287[0][0]
# __________________________________________________________________________________________________
# batch_normalization_277 (BatchN (None, 16, 16, 128)  512         add_91[0][0]
# __________________________________________________________________________________________________
# activation_277 (Activation)     (None, 16, 16, 128)  0           batch_normalization_277[0][0]
# __________________________________________________________________________________________________
# conv2d_289 (Conv2D)             (None, 16, 16, 64)   8256        activation_277[0][0]
# __________________________________________________________________________________________________
# batch_normalization_278 (BatchN (None, 16, 16, 64)   256         conv2d_289[0][0]
# __________________________________________________________________________________________________
# activation_278 (Activation)     (None, 16, 16, 64)   0           batch_normalization_278[0][0]
# __________________________________________________________________________________________________
# conv2d_290 (Conv2D)             (None, 16, 16, 64)   36928       activation_278[0][0]
# __________________________________________________________________________________________________
# batch_normalization_279 (BatchN (None, 16, 16, 64)   256         conv2d_290[0][0]
# __________________________________________________________________________________________________
# activation_279 (Activation)     (None, 16, 16, 64)   0           batch_normalization_279[0][0]
# __________________________________________________________________________________________________
# conv2d_291 (Conv2D)             (None, 16, 16, 128)  8320        activation_279[0][0]
# __________________________________________________________________________________________________
# add_92 (Add)                    (None, 16, 16, 128)  0           add_91[0][0]
#                                                                  conv2d_291[0][0]
# __________________________________________________________________________________________________
# batch_normalization_280 (BatchN (None, 16, 16, 128)  512         add_92[0][0]
# __________________________________________________________________________________________________
# activation_280 (Activation)     (None, 16, 16, 128)  0           batch_normalization_280[0][0]
# __________________________________________________________________________________________________
# conv2d_292 (Conv2D)             (None, 16, 16, 64)   8256        activation_280[0][0]
# __________________________________________________________________________________________________
# batch_normalization_281 (BatchN (None, 16, 16, 64)   256         conv2d_292[0][0]
# __________________________________________________________________________________________________
# activation_281 (Activation)     (None, 16, 16, 64)   0           batch_normalization_281[0][0]
# __________________________________________________________________________________________________
# conv2d_293 (Conv2D)             (None, 16, 16, 64)   36928       activation_281[0][0]
# __________________________________________________________________________________________________
# batch_normalization_282 (BatchN (None, 16, 16, 64)   256         conv2d_293[0][0]
# __________________________________________________________________________________________________
# activation_282 (Activation)     (None, 16, 16, 64)   0           batch_normalization_282[0][0]
# __________________________________________________________________________________________________
# conv2d_294 (Conv2D)             (None, 16, 16, 128)  8320        activation_282[0][0]
# __________________________________________________________________________________________________
# add_93 (Add)                    (None, 16, 16, 128)  0           add_92[0][0]
#                                                                  conv2d_294[0][0]
# __________________________________________________________________________________________________
# batch_normalization_283 (BatchN (None, 16, 16, 128)  512         add_93[0][0]
# __________________________________________________________________________________________________
# activation_283 (Activation)     (None, 16, 16, 128)  0           batch_normalization_283[0][0]
# __________________________________________________________________________________________________
# conv2d_295 (Conv2D)             (None, 16, 16, 64)   8256        activation_283[0][0]
# __________________________________________________________________________________________________
# batch_normalization_284 (BatchN (None, 16, 16, 64)   256         conv2d_295[0][0]
# __________________________________________________________________________________________________
# activation_284 (Activation)     (None, 16, 16, 64)   0           batch_normalization_284[0][0]
# __________________________________________________________________________________________________
# conv2d_296 (Conv2D)             (None, 16, 16, 64)   36928       activation_284[0][0]
# __________________________________________________________________________________________________
# batch_normalization_285 (BatchN (None, 16, 16, 64)   256         conv2d_296[0][0]
# __________________________________________________________________________________________________
# activation_285 (Activation)     (None, 16, 16, 64)   0           batch_normalization_285[0][0]
# __________________________________________________________________________________________________
# conv2d_297 (Conv2D)             (None, 16, 16, 128)  8320        activation_285[0][0]
# __________________________________________________________________________________________________
# add_94 (Add)                    (None, 16, 16, 128)  0           add_93[0][0]
#                                                                  conv2d_297[0][0]
# __________________________________________________________________________________________________
# batch_normalization_286 (BatchN (None, 16, 16, 128)  512         add_94[0][0]
# __________________________________________________________________________________________________
# activation_286 (Activation)     (None, 16, 16, 128)  0           batch_normalization_286[0][0]
# __________________________________________________________________________________________________
# conv2d_298 (Conv2D)             (None, 16, 16, 64)   8256        activation_286[0][0]
# __________________________________________________________________________________________________
# batch_normalization_287 (BatchN (None, 16, 16, 64)   256         conv2d_298[0][0]
# __________________________________________________________________________________________________
# activation_287 (Activation)     (None, 16, 16, 64)   0           batch_normalization_287[0][0]
# __________________________________________________________________________________________________
# conv2d_299 (Conv2D)             (None, 16, 16, 64)   36928       activation_287[0][0]
# __________________________________________________________________________________________________
# batch_normalization_288 (BatchN (None, 16, 16, 64)   256         conv2d_299[0][0]
# __________________________________________________________________________________________________
# activation_288 (Activation)     (None, 16, 16, 64)   0           batch_normalization_288[0][0]
# __________________________________________________________________________________________________
# conv2d_300 (Conv2D)             (None, 16, 16, 128)  8320        activation_288[0][0]
# __________________________________________________________________________________________________
# add_95 (Add)                    (None, 16, 16, 128)  0           add_94[0][0]
#                                                                  conv2d_300[0][0]
# __________________________________________________________________________________________________
# batch_normalization_289 (BatchN (None, 16, 16, 128)  512         add_95[0][0]
# __________________________________________________________________________________________________
# activation_289 (Activation)     (None, 16, 16, 128)  0           batch_normalization_289[0][0]
# __________________________________________________________________________________________________
# conv2d_301 (Conv2D)             (None, 16, 16, 64)   8256        activation_289[0][0]
# __________________________________________________________________________________________________
# batch_normalization_290 (BatchN (None, 16, 16, 64)   256         conv2d_301[0][0]
# __________________________________________________________________________________________________
# activation_290 (Activation)     (None, 16, 16, 64)   0           batch_normalization_290[0][0]
# __________________________________________________________________________________________________
# conv2d_302 (Conv2D)             (None, 16, 16, 64)   36928       activation_290[0][0]
# __________________________________________________________________________________________________
# batch_normalization_291 (BatchN (None, 16, 16, 64)   256         conv2d_302[0][0]
# __________________________________________________________________________________________________
# activation_291 (Activation)     (None, 16, 16, 64)   0           batch_normalization_291[0][0]
# __________________________________________________________________________________________________
# conv2d_303 (Conv2D)             (None, 16, 16, 128)  8320        activation_291[0][0]
# __________________________________________________________________________________________________
# add_96 (Add)                    (None, 16, 16, 128)  0           add_95[0][0]
#                                                                  conv2d_303[0][0]
# __________________________________________________________________________________________________
# batch_normalization_292 (BatchN (None, 16, 16, 128)  512         add_96[0][0]
# __________________________________________________________________________________________________
# activation_292 (Activation)     (None, 16, 16, 128)  0           batch_normalization_292[0][0]
# __________________________________________________________________________________________________
# conv2d_304 (Conv2D)             (None, 16, 16, 64)   8256        activation_292[0][0]
# __________________________________________________________________________________________________
# batch_normalization_293 (BatchN (None, 16, 16, 64)   256         conv2d_304[0][0]
# __________________________________________________________________________________________________
# activation_293 (Activation)     (None, 16, 16, 64)   0           batch_normalization_293[0][0]
# __________________________________________________________________________________________________
# conv2d_305 (Conv2D)             (None, 16, 16, 64)   36928       activation_293[0][0]
# __________________________________________________________________________________________________
# batch_normalization_294 (BatchN (None, 16, 16, 64)   256         conv2d_305[0][0]
# __________________________________________________________________________________________________
# activation_294 (Activation)     (None, 16, 16, 64)   0           batch_normalization_294[0][0]
# __________________________________________________________________________________________________
# conv2d_306 (Conv2D)             (None, 16, 16, 128)  8320        activation_294[0][0]
# __________________________________________________________________________________________________
# add_97 (Add)                    (None, 16, 16, 128)  0           add_96[0][0]
#                                                                  conv2d_306[0][0]
# __________________________________________________________________________________________________
# batch_normalization_295 (BatchN (None, 16, 16, 128)  512         add_97[0][0]
# __________________________________________________________________________________________________
# activation_295 (Activation)     (None, 16, 16, 128)  0           batch_normalization_295[0][0]
# __________________________________________________________________________________________________
# conv2d_307 (Conv2D)             (None, 16, 16, 64)   8256        activation_295[0][0]
# __________________________________________________________________________________________________
# batch_normalization_296 (BatchN (None, 16, 16, 64)   256         conv2d_307[0][0]
# __________________________________________________________________________________________________
# activation_296 (Activation)     (None, 16, 16, 64)   0           batch_normalization_296[0][0]
# __________________________________________________________________________________________________
# conv2d_308 (Conv2D)             (None, 16, 16, 64)   36928       activation_296[0][0]
# __________________________________________________________________________________________________
# batch_normalization_297 (BatchN (None, 16, 16, 64)   256         conv2d_308[0][0]
# __________________________________________________________________________________________________
# activation_297 (Activation)     (None, 16, 16, 64)   0           batch_normalization_297[0][0]
# __________________________________________________________________________________________________
# conv2d_309 (Conv2D)             (None, 16, 16, 128)  8320        activation_297[0][0]
# __________________________________________________________________________________________________
# add_98 (Add)                    (None, 16, 16, 128)  0           add_97[0][0]
#                                                                  conv2d_309[0][0]
# __________________________________________________________________________________________________
# batch_normalization_298 (BatchN (None, 16, 16, 128)  512         add_98[0][0]
# __________________________________________________________________________________________________
# activation_298 (Activation)     (None, 16, 16, 128)  0           batch_normalization_298[0][0]
# __________________________________________________________________________________________________
# conv2d_310 (Conv2D)             (None, 16, 16, 64)   8256        activation_298[0][0]
# __________________________________________________________________________________________________
# batch_normalization_299 (BatchN (None, 16, 16, 64)   256         conv2d_310[0][0]
# __________________________________________________________________________________________________
# activation_299 (Activation)     (None, 16, 16, 64)   0           batch_normalization_299[0][0]
# __________________________________________________________________________________________________
# conv2d_311 (Conv2D)             (None, 16, 16, 64)   36928       activation_299[0][0]
# __________________________________________________________________________________________________
# batch_normalization_300 (BatchN (None, 16, 16, 64)   256         conv2d_311[0][0]
# __________________________________________________________________________________________________
# activation_300 (Activation)     (None, 16, 16, 64)   0           batch_normalization_300[0][0]
# __________________________________________________________________________________________________
# conv2d_312 (Conv2D)             (None, 16, 16, 128)  8320        activation_300[0][0]
# __________________________________________________________________________________________________
# add_99 (Add)                    (None, 16, 16, 128)  0           add_98[0][0]
#                                                                  conv2d_312[0][0]
# __________________________________________________________________________________________________
# batch_normalization_301 (BatchN (None, 16, 16, 128)  512         add_99[0][0]
# __________________________________________________________________________________________________
# activation_301 (Activation)     (None, 16, 16, 128)  0           batch_normalization_301[0][0]
# __________________________________________________________________________________________________
# conv2d_313 (Conv2D)             (None, 16, 16, 64)   8256        activation_301[0][0]
# __________________________________________________________________________________________________
# batch_normalization_302 (BatchN (None, 16, 16, 64)   256         conv2d_313[0][0]
# __________________________________________________________________________________________________
# activation_302 (Activation)     (None, 16, 16, 64)   0           batch_normalization_302[0][0]
# __________________________________________________________________________________________________
# conv2d_314 (Conv2D)             (None, 16, 16, 64)   36928       activation_302[0][0]
# __________________________________________________________________________________________________
# batch_normalization_303 (BatchN (None, 16, 16, 64)   256         conv2d_314[0][0]
# __________________________________________________________________________________________________
# activation_303 (Activation)     (None, 16, 16, 64)   0           batch_normalization_303[0][0]
# __________________________________________________________________________________________________
# conv2d_315 (Conv2D)             (None, 16, 16, 128)  8320        activation_303[0][0]
# __________________________________________________________________________________________________
# add_100 (Add)                   (None, 16, 16, 128)  0           add_99[0][0]
#                                                                  conv2d_315[0][0]
# __________________________________________________________________________________________________
# batch_normalization_304 (BatchN (None, 16, 16, 128)  512         add_100[0][0]
# __________________________________________________________________________________________________
# activation_304 (Activation)     (None, 16, 16, 128)  0           batch_normalization_304[0][0]
# __________________________________________________________________________________________________
# conv2d_316 (Conv2D)             (None, 16, 16, 64)   8256        activation_304[0][0]
# __________________________________________________________________________________________________
# batch_normalization_305 (BatchN (None, 16, 16, 64)   256         conv2d_316[0][0]
# __________________________________________________________________________________________________
# activation_305 (Activation)     (None, 16, 16, 64)   0           batch_normalization_305[0][0]
# __________________________________________________________________________________________________
# conv2d_317 (Conv2D)             (None, 16, 16, 64)   36928       activation_305[0][0]
# ...
#                                                                  conv2d_337[0][0]
# __________________________________________________________________________________________________
# batch_normalization_325 (BatchN (None, 8, 8, 256)    1024        add_107[0][0]
# __________________________________________________________________________________________________
# activation_325 (Activation)     (None, 8, 8, 256)    0           batch_normalization_325[0][0]
# __________________________________________________________________________________________________
# conv2d_338 (Conv2D)             (None, 8, 8, 128)    32896       activation_325[0][0]
# __________________________________________________________________________________________________
# batch_normalization_326 (BatchN (None, 8, 8, 128)    512         conv2d_338[0][0]
# __________________________________________________________________________________________________
# activation_326 (Activation)     (None, 8, 8, 128)    0           batch_normalization_326[0][0]
# __________________________________________________________________________________________________
# conv2d_339 (Conv2D)             (None, 8, 8, 128)    147584      activation_326[0][0]
# __________________________________________________________________________________________________
# batch_normalization_327 (BatchN (None, 8, 8, 128)    512         conv2d_339[0][0]
# __________________________________________________________________________________________________
# activation_327 (Activation)     (None, 8, 8, 128)    0           batch_normalization_327[0][0]
# __________________________________________________________________________________________________
# conv2d_340 (Conv2D)             (None, 8, 8, 256)    33024       activation_327[0][0]
# __________________________________________________________________________________________________
# add_108 (Add)                   (None, 8, 8, 256)    0           add_107[0][0]
#                                                                  conv2d_340[0][0]
# __________________________________________________________________________________________________
# batch_normalization_328 (BatchN (None, 8, 8, 256)    1024        add_108[0][0]
# __________________________________________________________________________________________________
# activation_328 (Activation)     (None, 8, 8, 256)    0           batch_normalization_328[0][0]
# __________________________________________________________________________________________________
# conv2d_341 (Conv2D)             (None, 8, 8, 128)    32896       activation_328[0][0]
# __________________________________________________________________________________________________
# batch_normalization_329 (BatchN (None, 8, 8, 128)    512         conv2d_341[0][0]
# __________________________________________________________________________________________________
# activation_329 (Activation)     (None, 8, 8, 128)    0           batch_normalization_329[0][0]
# __________________________________________________________________________________________________
# conv2d_342 (Conv2D)             (None, 8, 8, 128)    147584      activation_329[0][0]
# __________________________________________________________________________________________________
# batch_normalization_330 (BatchN (None, 8, 8, 128)    512         conv2d_342[0][0]
# __________________________________________________________________________________________________
# activation_330 (Activation)     (None, 8, 8, 128)    0           batch_normalization_330[0][0]
# __________________________________________________________________________________________________
# conv2d_343 (Conv2D)             (None, 8, 8, 256)    33024       activation_330[0][0]
# __________________________________________________________________________________________________
# add_109 (Add)                   (None, 8, 8, 256)    0           add_108[0][0]
#                                                                  conv2d_343[0][0]
# __________________________________________________________________________________________________
# batch_normalization_331 (BatchN (None, 8, 8, 256)    1024        add_109[0][0]
# __________________________________________________________________________________________________
# activation_331 (Activation)     (None, 8, 8, 256)    0           batch_normalization_331[0][0]
# __________________________________________________________________________________________________
# conv2d_344 (Conv2D)             (None, 8, 8, 128)    32896       activation_331[0][0]
# __________________________________________________________________________________________________
# batch_normalization_332 (BatchN (None, 8, 8, 128)    512         conv2d_344[0][0]
# __________________________________________________________________________________________________
# activation_332 (Activation)     (None, 8, 8, 128)    0           batch_normalization_332[0][0]
# __________________________________________________________________________________________________
# conv2d_345 (Conv2D)             (None, 8, 8, 128)    147584      activation_332[0][0]
# __________________________________________________________________________________________________
# batch_normalization_333 (BatchN (None, 8, 8, 128)    512         conv2d_345[0][0]
# __________________________________________________________________________________________________
# activation_333 (Activation)     (None, 8, 8, 128)    0           batch_normalization_333[0][0]
# __________________________________________________________________________________________________
# conv2d_346 (Conv2D)             (None, 8, 8, 256)    33024       activation_333[0][0]
# __________________________________________________________________________________________________
# add_110 (Add)                   (None, 8, 8, 256)    0           add_109[0][0]
#                                                                  conv2d_346[0][0]
# __________________________________________________________________________________________________
# batch_normalization_334 (BatchN (None, 8, 8, 256)    1024        add_110[0][0]
# __________________________________________________________________________________________________
# activation_334 (Activation)     (None, 8, 8, 256)    0           batch_normalization_334[0][0]
# __________________________________________________________________________________________________
# conv2d_347 (Conv2D)             (None, 8, 8, 128)    32896       activation_334[0][0]
# __________________________________________________________________________________________________
# batch_normalization_335 (BatchN (None, 8, 8, 128)    512         conv2d_347[0][0]
# __________________________________________________________________________________________________
# activation_335 (Activation)     (None, 8, 8, 128)    0           batch_normalization_335[0][0]
# __________________________________________________________________________________________________
# conv2d_348 (Conv2D)             (None, 8, 8, 128)    147584      activation_335[0][0]
# __________________________________________________________________________________________________
# batch_normalization_336 (BatchN (None, 8, 8, 128)    512         conv2d_348[0][0]
# __________________________________________________________________________________________________
# activation_336 (Activation)     (None, 8, 8, 128)    0           batch_normalization_336[0][0]
# __________________________________________________________________________________________________
# conv2d_349 (Conv2D)             (None, 8, 8, 256)    33024       activation_336[0][0]
# __________________________________________________________________________________________________
# add_111 (Add)                   (None, 8, 8, 256)    0           add_110[0][0]
#                                                                  conv2d_349[0][0]
# __________________________________________________________________________________________________
# batch_normalization_337 (BatchN (None, 8, 8, 256)    1024        add_111[0][0]
# __________________________________________________________________________________________________
# activation_337 (Activation)     (None, 8, 8, 256)    0           batch_normalization_337[0][0]
# __________________________________________________________________________________________________
# conv2d_350 (Conv2D)             (None, 8, 8, 128)    32896       activation_337[0][0]
# __________________________________________________________________________________________________
# batch_normalization_338 (BatchN (None, 8, 8, 128)    512         conv2d_350[0][0]
# __________________________________________________________________________________________________
# activation_338 (Activation)     (None, 8, 8, 128)    0           batch_normalization_338[0][0]
# __________________________________________________________________________________________________
# conv2d_351 (Conv2D)             (None, 8, 8, 128)    147584      activation_338[0][0]
# __________________________________________________________________________________________________
# batch_normalization_339 (BatchN (None, 8, 8, 128)    512         conv2d_351[0][0]
# __________________________________________________________________________________________________
# activation_339 (Activation)     (None, 8, 8, 128)    0           batch_normalization_339[0][0]
# __________________________________________________________________________________________________
# conv2d_352 (Conv2D)             (None, 8, 8, 256)    33024       activation_339[0][0]
# __________________________________________________________________________________________________
# add_112 (Add)                   (None, 8, 8, 256)    0           add_111[0][0]
#                                                                  conv2d_352[0][0]
# __________________________________________________________________________________________________
# batch_normalization_340 (BatchN (None, 8, 8, 256)    1024        add_112[0][0]
# __________________________________________________________________________________________________
# activation_340 (Activation)     (None, 8, 8, 256)    0           batch_normalization_340[0][0]
# __________________________________________________________________________________________________
# conv2d_353 (Conv2D)             (None, 8, 8, 128)    32896       activation_340[0][0]
# __________________________________________________________________________________________________
# batch_normalization_341 (BatchN (None, 8, 8, 128)    512         conv2d_353[0][0]
# __________________________________________________________________________________________________
# activation_341 (Activation)     (None, 8, 8, 128)    0           batch_normalization_341[0][0]
# __________________________________________________________________________________________________
# conv2d_354 (Conv2D)             (None, 8, 8, 128)    147584      activation_341[0][0]
# __________________________________________________________________________________________________
# batch_normalization_342 (BatchN (None, 8, 8, 128)    512         conv2d_354[0][0]
# __________________________________________________________________________________________________
# activation_342 (Activation)     (None, 8, 8, 128)    0           batch_normalization_342[0][0]
# __________________________________________________________________________________________________
# conv2d_355 (Conv2D)             (None, 8, 8, 256)    33024       activation_342[0][0]
# __________________________________________________________________________________________________
# add_113 (Add)                   (None, 8, 8, 256)    0           add_112[0][0]
#                                                                  conv2d_355[0][0]
# __________________________________________________________________________________________________
# batch_normalization_343 (BatchN (None, 8, 8, 256)    1024        add_113[0][0]
# __________________________________________________________________________________________________
# activation_343 (Activation)     (None, 8, 8, 256)    0           batch_normalization_343[0][0]
# __________________________________________________________________________________________________
# conv2d_356 (Conv2D)             (None, 8, 8, 128)    32896       activation_343[0][0]
# __________________________________________________________________________________________________
# batch_normalization_344 (BatchN (None, 8, 8, 128)    512         conv2d_356[0][0]
# __________________________________________________________________________________________________
# activation_344 (Activation)     (None, 8, 8, 128)    0           batch_normalization_344[0][0]
# __________________________________________________________________________________________________
# conv2d_357 (Conv2D)             (None, 8, 8, 128)    147584      activation_344[0][0]
# __________________________________________________________________________________________________
# batch_normalization_345 (BatchN (None, 8, 8, 128)    512         conv2d_357[0][0]
# __________________________________________________________________________________________________
# activation_345 (Activation)     (None, 8, 8, 128)    0           batch_normalization_345[0][0]
# __________________________________________________________________________________________________
# conv2d_358 (Conv2D)             (None, 8, 8, 256)    33024       activation_345[0][0]
# __________________________________________________________________________________________________
# add_114 (Add)                   (None, 8, 8, 256)    0           add_113[0][0]
#                                                                  conv2d_358[0][0]
# __________________________________________________________________________________________________
# batch_normalization_346 (BatchN (None, 8, 8, 256)    1024        add_114[0][0]
# __________________________________________________________________________________________________
# activation_346 (Activation)     (None, 8, 8, 256)    0           batch_normalization_346[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 1, 1, 256)    0           activation_346[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 256)          0           average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 10)           2570        flatten_4[0][0]
# ==================================================================================================
# Total params: 3,323,210
# Trainable params: 3,302,442
# Non-trainable params: 20,768
# __________________________________________________________________________________________________
# ResNet110v2

# %%
# Training
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              steps_per_epoch=x_train.shape[0] // batch_size,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, steps_per_epoch=x_train.shape[0] // batch_size, verbose=1, workers=4,
                        callbacks=callbacks,)
# Out:
# Using real-time data augmentation.
# Epoch 1/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 222s 142ms/step - loss: 2.3873 - acc: 0.4887 - val_loss: 1.7991 - val_acc: 0.5507
#
# Epoch 00001: val_acc improved from -inf to 0.55070, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 2/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 1.5250 - acc: 0.6202 - val_loss: 1.7509 - val_acc: 0.5713
#
# Epoch 00002: val_acc improved from 0.55070 to 0.57130, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 3/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 1.2880 - acc: 0.6821 - val_loss: 1.3985 - val_acc: 0.6394
#
# Epoch 00003: val_acc improved from 0.57130 to 0.63940, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 4/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 1.1608 - acc: 0.7188 - val_loss: 1.4978 - val_acc: 0.6354
#
# Epoch 00004: val_acc did not improve from 0.63940
# Epoch 5/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 1.0655 - acc: 0.7477 - val_loss: 1.3223 - val_acc: 0.6747
#
# Epoch 00005: val_acc improved from 0.63940 to 0.67470, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 6/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.9989 - acc: 0.7669 - val_loss: 1.2138 - val_acc: 0.6964
#
# Epoch 00006: val_acc improved from 0.67470 to 0.69640, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 7/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.9444 - acc: 0.7805 - val_loss: 1.4147 - val_acc: 0.6645
#
# Epoch 00007: val_acc did not improve from 0.69640
# Epoch 8/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.9006 - acc: 0.7921 - val_loss: 1.3192 - val_acc: 0.6608
#
# Epoch 00008: val_acc did not improve from 0.69640
# Epoch 9/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.8623 - acc: 0.8009 - val_loss: 1.0659 - val_acc: 0.7372
#
# Epoch 00009: val_acc improved from 0.69640 to 0.73720, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 10/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.8322 - acc: 0.8093 - val_loss: 1.0319 - val_acc: 0.7638
#
# Epoch 00010: val_acc improved from 0.73720 to 0.76380, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 11/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.8025 - acc: 0.8172 - val_loss: 1.1923 - val_acc: 0.7082
#
# Epoch 00011: val_acc did not improve from 0.76380
# Epoch 12/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.7787 - acc: 0.8229 - val_loss: 1.1846 - val_acc: 0.7233
#
# Epoch 00012: val_acc did not improve from 0.76380
# Epoch 13/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.7545 - acc: 0.8299 - val_loss: 0.9866 - val_acc: 0.7585
#
# Epoch 00013: val_acc did not improve from 0.76380
# Epoch 14/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.7355 - acc: 0.8347 - val_loss: 1.0757 - val_acc: 0.7292
#
# Epoch 00014: val_acc did not improve from 0.76380
# Epoch 15/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.7228 - acc: 0.8382 - val_loss: 0.8851 - val_acc: 0.7865
#
# Epoch 00015: val_acc improved from 0.76380 to 0.78650, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 16/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.7077 - acc: 0.8427 - val_loss: 0.7723 - val_acc: 0.8218
#
# Epoch 00016: val_acc improved from 0.78650 to 0.82180, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 17/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.6907 - acc: 0.8488 - val_loss: 0.8590 - val_acc: 0.8076
#
# Epoch 00017: val_acc did not improve from 0.82180
# Epoch 18/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.6778 - acc: 0.8506 - val_loss: 0.8215 - val_acc: 0.8052
#
# Epoch 00018: val_acc did not improve from 0.82180
# Epoch 19/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.6659 - acc: 0.8506 - val_loss: 1.1420 - val_acc: 0.7383
#
# Epoch 00019: val_acc did not improve from 0.82180
# Epoch 20/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.6551 - acc: 0.8562 - val_loss: 0.8369 - val_acc: 0.8002
#
# Epoch 00020: val_acc did not improve from 0.82180
# Epoch 21/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.6469 - acc: 0.8582 - val_loss: 0.8463 - val_acc: 0.8092
#
# Epoch 00021: val_acc did not improve from 0.82180
# Epoch 22/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.6387 - acc: 0.8605 - val_loss: 0.8581 - val_acc: 0.8099
#
# Epoch 00022: val_acc did not improve from 0.82180
# Epoch 23/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 117ms/step - loss: 0.6256 - acc: 0.8644 - val_loss: 0.7835 - val_acc: 0.8202
#
# Epoch 00023: val_acc did not improve from 0.82180
# Epoch 24/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.6225 - acc: 0.8661 - val_loss: 0.9347 - val_acc: 0.7831
#
# Epoch 00024: val_acc did not improve from 0.82180
# Epoch 25/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.6140 - acc: 0.8680 - val_loss: 0.8024 - val_acc: 0.8055
#
# Epoch 00025: val_acc did not improve from 0.82180
# Epoch 26/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.6061 - acc: 0.8703 - val_loss: 0.7876 - val_acc: 0.8145
#
# Epoch 00026: val_acc did not improve from 0.82180
# Epoch 27/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.5993 - acc: 0.8709 - val_loss: 0.9303 - val_acc: 0.7905
#
# Epoch 00027: val_acc did not improve from 0.82180
# Epoch 28/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.5917 - acc: 0.8723 - val_loss: 0.6979 - val_acc: 0.8409
#
# Epoch 00028: val_acc improved from 0.82180 to 0.84090, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 29/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.5863 - acc: 0.8748 - val_loss: 0.6989 - val_acc: 0.8462
#
# Epoch 00029: val_acc improved from 0.84090 to 0.84620, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 30/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.5810 - acc: 0.8762 - val_loss: 0.6713 - val_acc: 0.8485
#
# Epoch 00030: val_acc improved from 0.84620 to 0.84850, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 31/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.5760 - acc: 0.8767 - val_loss: 0.7964 - val_acc: 0.8199
#
# Epoch 00031: val_acc did not improve from 0.84850
# Epoch 32/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.5707 - acc: 0.8792 - val_loss: 0.8235 - val_acc: 0.8190
#
# Epoch 00032: val_acc did not improve from 0.84850
# Epoch 33/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.5660 - acc: 0.8808 - val_loss: 0.6800 - val_acc: 0.8513
#
# Epoch 00033: val_acc improved from 0.84850 to 0.85130, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 34/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.5643 - acc: 0.8800 - val_loss: 0.7251 - val_acc: 0.8313
#
# Epoch 00034: val_acc did not improve from 0.85130
# Epoch 35/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.5537 - acc: 0.8828 - val_loss: 0.7148 - val_acc: 0.8430
#
# Epoch 00035: val_acc did not improve from 0.85130
# Epoch 36/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.5508 - acc: 0.8844 - val_loss: 0.9890 - val_acc: 0.7657
#
# Epoch 00036: val_acc did not improve from 0.85130
# Epoch 37/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.5471 - acc: 0.8863 - val_loss: 0.7217 - val_acc: 0.8373
#
# Epoch 00037: val_acc did not improve from 0.85130
# Epoch 38/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.5447 - acc: 0.8862 - val_loss: 0.7146 - val_acc: 0.8342
#
# Epoch 00038: val_acc did not improve from 0.85130
# Epoch 39/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.5418 - acc: 0.8880 - val_loss: 0.7438 - val_acc: 0.8286
#
# Epoch 00039: val_acc did not improve from 0.85130
# Epoch 40/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 182s 116ms/step - loss: 0.5372 - acc: 0.8900 - val_loss: 0.6782 - val_acc: 0.8509
#
# Epoch 00040: val_acc did not improve from 0.85130
# Epoch 41/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.5374 - acc: 0.8875 - val_loss: 0.6466 - val_acc: 0.8570
#
# Epoch 00041: val_acc improved from 0.85130 to 0.85700, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 42/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.5301 - acc: 0.8899 - val_loss: 0.7094 - val_acc: 0.8403
#
# Epoch 00042: val_acc did not improve from 0.85700
# Epoch 43/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.5269 - acc: 0.8910 - val_loss: 0.6901 - val_acc: 0.8458
#
# Epoch 00043: val_acc did not improve from 0.85700
# Epoch 44/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.5248 - acc: 0.8923 - val_loss: 0.8051 - val_acc: 0.8202
#
# Epoch 00044: val_acc did not improve from 0.85700
# Epoch 45/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.5264 - acc: 0.8917 - val_loss: 0.6680 - val_acc: 0.8541
#
# Epoch 00045: val_acc did not improve from 0.85700
# Epoch 46/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.5230 - acc: 0.8936 - val_loss: 0.6399 - val_acc: 0.8607
#
# Epoch 00046: val_acc improved from 0.85700 to 0.86070, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 47/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.5160 - acc: 0.8938 - val_loss: 0.6821 - val_acc: 0.8463
#
# Epoch 00047: val_acc did not improve from 0.86070
# Epoch 48/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.5107 - acc: 0.8962 - val_loss: 0.7518 - val_acc: 0.8392
#
# Epoch 00048: val_acc did not improve from 0.86070
# Epoch 49/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 179s 114ms/step - loss: 0.5141 - acc: 0.8948 - val_loss: 0.8550 - val_acc: 0.8052
#
# Epoch 00049: val_acc did not improve from 0.86070
# Epoch 50/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 175s 112ms/step - loss: 0.5117 - acc: 0.8942 - val_loss: 0.6197 - val_acc: 0.8621
#
# Epoch 00050: val_acc improved from 0.86070 to 0.86210, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 51/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 182s 116ms/step - loss: 0.5073 - acc: 0.8970 - val_loss: 0.7380 - val_acc: 0.8335
#
# Epoch 00051: val_acc did not improve from 0.86210
# Epoch 52/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 180s 115ms/step - loss: 0.5050 - acc: 0.8983 - val_loss: 0.6534 - val_acc: 0.8557
#
# Epoch 00052: val_acc did not improve from 0.86210
# Epoch 53/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 177s 113ms/step - loss: 0.5051 - acc: 0.8971 - val_loss: 0.6446 - val_acc: 0.8588
#
# Epoch 00053: val_acc did not improve from 0.86210
# Epoch 54/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.5012 - acc: 0.8987 - val_loss: 0.6817 - val_acc: 0.8499
#
# Epoch 00054: val_acc did not improve from 0.86210
# Epoch 55/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.5001 - acc: 0.8994 - val_loss: 0.6789 - val_acc: 0.8512
#
# Epoch 00055: val_acc did not improve from 0.86210
# Epoch 56/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 181s 116ms/step - loss: 0.4948 - acc: 0.8991 - val_loss: 0.7165 - val_acc: 0.8354
#
# Epoch 00056: val_acc did not improve from 0.86210
# Epoch 57/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 180s 115ms/step - loss: 0.4937 - acc: 0.9017 - val_loss: 0.6537 - val_acc: 0.8537
#
# Epoch 00057: val_acc did not improve from 0.86210
# Epoch 58/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 179s 115ms/step - loss: 0.4984 - acc: 0.8983 - val_loss: 0.6152 - val_acc: 0.8691
#
# Epoch 00058: val_acc improved from 0.86210 to 0.86910, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 59/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.4889 - acc: 0.9014 - val_loss: 0.7823 - val_acc: 0.8258
#
# Epoch 00059: val_acc did not improve from 0.86910
# Epoch 60/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.4942 - acc: 0.9017 - val_loss: 0.6735 - val_acc: 0.8542
#
# Epoch 00060: val_acc did not improve from 0.86910
# Epoch 61/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.4887 - acc: 0.9025 - val_loss: 0.8434 - val_acc: 0.8125
#
# Epoch 00061: val_acc did not improve from 0.86910
# Epoch 62/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.4835 - acc: 0.9032 - val_loss: 0.6391 - val_acc: 0.8580
#
# Epoch 00062: val_acc did not improve from 0.86910
# Epoch 63/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 185s 118ms/step - loss: 0.4841 - acc: 0.9027 - val_loss: 0.6013 - val_acc: 0.8711
#
# Epoch 00063: val_acc improved from 0.86910 to 0.87110, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 64/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.4820 - acc: 0.9044 - val_loss: 0.5907 - val_acc: 0.8719
#
# Epoch 00064: val_acc improved from 0.87110 to 0.87190, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 65/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.4803 - acc: 0.9037 - val_loss: 0.7723 - val_acc: 0.8284
#
# Epoch 00065: val_acc did not improve from 0.87190
# Epoch 66/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.4781 - acc: 0.9041 - val_loss: 0.6796 - val_acc: 0.8538
#
# Epoch 00066: val_acc did not improve from 0.87190
# Epoch 67/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.4737 - acc: 0.9074 - val_loss: 0.6884 - val_acc: 0.8525
#
# Epoch 00067: val_acc did not improve from 0.87190
# Epoch 68/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.4816 - acc: 0.9030 - val_loss: 0.6293 - val_acc: 0.8595
#
# Epoch 00068: val_acc did not improve from 0.87190
# Epoch 69/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.4748 - acc: 0.9054 - val_loss: 0.6920 - val_acc: 0.8479
#
# Epoch 00069: val_acc did not improve from 0.87190
# Epoch 70/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.4721 - acc: 0.9056 - val_loss: 0.6365 - val_acc: 0.8556
#
# Epoch 00070: val_acc did not improve from 0.87190
# Epoch 71/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.4675 - acc: 0.9078 - val_loss: 0.6839 - val_acc: 0.8516
#
# Epoch 00071: val_acc did not improve from 0.87190
# Epoch 72/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.4702 - acc: 0.9079 - val_loss: 0.7221 - val_acc: 0.8436
#
# Epoch 00072: val_acc did not improve from 0.87190
# Epoch 73/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.4691 - acc: 0.9063 - val_loss: 0.6334 - val_acc: 0.8629
#
# Epoch 00073: val_acc did not improve from 0.87190
# Epoch 74/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.4645 - acc: 0.9078 - val_loss: 0.5834 - val_acc: 0.8718
#
# Epoch 00074: val_acc did not improve from 0.87190
# Epoch 75/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.4669 - acc: 0.9081 - val_loss: 0.5687 - val_acc: 0.8762
#
# Epoch 00075: val_acc improved from 0.87190 to 0.87620, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 76/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.4651 - acc: 0.9071 - val_loss: 0.6258 - val_acc: 0.8601
#
# Epoch 00076: val_acc did not improve from 0.87620
# Epoch 77/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.4666 - acc: 0.9073 - val_loss: 0.6078 - val_acc: 0.8664
#
# Epoch 00077: val_acc did not improve from 0.87620
# Epoch 78/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.4593 - acc: 0.9100 - val_loss: 0.6869 - val_acc: 0.8448
#
# Epoch 00078: val_acc did not improve from 0.87620
# Epoch 79/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.4615 - acc: 0.9087 - val_loss: 0.5690 - val_acc: 0.8746
#
# Epoch 00079: val_acc did not improve from 0.87620
# Epoch 80/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.4587 - acc: 0.9094 - val_loss: 0.6103 - val_acc: 0.8710
#
# Epoch 00080: val_acc did not improve from 0.87620
# Epoch 81/150
# Learning rate:  0.001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.4586 - acc: 0.9089 - val_loss: 0.5904 - val_acc: 0.8731
#
# Epoch 00081: val_acc did not improve from 0.87620
# Epoch 82/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.3772 - acc: 0.9386 - val_loss: 0.4506 - val_acc: 0.9144
#
# Epoch 00082: val_acc improved from 0.87620 to 0.91440, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 83/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 181s 116ms/step - loss: 0.3458 - acc: 0.9475 - val_loss: 0.4399 - val_acc: 0.9182
#
# Epoch 00083: val_acc improved from 0.91440 to 0.91820, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 84/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 179s 115ms/step - loss: 0.3271 - acc: 0.9535 - val_loss: 0.4344 - val_acc: 0.9186
#
# Epoch 00084: val_acc improved from 0.91820 to 0.91860, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 85/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.3159 - acc: 0.9566 - val_loss: 0.4312 - val_acc: 0.9194
#
# Epoch 00085: val_acc improved from 0.91860 to 0.91940, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 86/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 176s 113ms/step - loss: 0.3097 - acc: 0.9568 - val_loss: 0.4306 - val_acc: 0.9217
#
# Epoch 00086: val_acc improved from 0.91940 to 0.92170, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 87/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 178s 114ms/step - loss: 0.2996 - acc: 0.9590 - val_loss: 0.4283 - val_acc: 0.9214
#
# Epoch 00087: val_acc did not improve from 0.92170
# Epoch 88/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 179s 115ms/step - loss: 0.2947 - acc: 0.9601 - val_loss: 0.4239 - val_acc: 0.9211
#
# Epoch 00088: val_acc did not improve from 0.92170
# Epoch 89/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 181s 116ms/step - loss: 0.2864 - acc: 0.9633 - val_loss: 0.4221 - val_acc: 0.9210
#
# Epoch 00089: val_acc did not improve from 0.92170
# Epoch 90/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 179s 115ms/step - loss: 0.2814 - acc: 0.9627 - val_loss: 0.4238 - val_acc: 0.9218
#
# Epoch 00090: val_acc improved from 0.92170 to 0.92180, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 91/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 181s 116ms/step - loss: 0.2752 - acc: 0.9642 - val_loss: 0.4274 - val_acc: 0.9194
#
# Epoch 00091: val_acc did not improve from 0.92180
# Epoch 92/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 181s 116ms/step - loss: 0.2702 - acc: 0.9650 - val_loss: 0.4203 - val_acc: 0.9208
#
# Epoch 00092: val_acc did not improve from 0.92180
# Epoch 93/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 175s 112ms/step - loss: 0.2651 - acc: 0.9674 - val_loss: 0.4212 - val_acc: 0.9216
#
# Epoch 00093: val_acc did not improve from 0.92180
# Epoch 94/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 176s 113ms/step - loss: 0.2608 - acc: 0.9671 - val_loss: 0.4211 - val_acc: 0.9197
#
# Epoch 00094: val_acc did not improve from 0.92180
# Epoch 95/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.2571 - acc: 0.9675 - val_loss: 0.4267 - val_acc: 0.9199
#
# Epoch 00095: val_acc did not improve from 0.92180
# Epoch 96/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.2519 - acc: 0.9689 - val_loss: 0.4194 - val_acc: 0.9187
#
# Epoch 00096: val_acc did not improve from 0.92180
# Epoch 97/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.2499 - acc: 0.9690 - val_loss: 0.4150 - val_acc: 0.9216
#
# Epoch 00097: val_acc did not improve from 0.92180
# Epoch 98/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.2456 - acc: 0.9693 - val_loss: 0.4174 - val_acc: 0.9238
#
# Epoch 00098: val_acc improved from 0.92180 to 0.92380, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 99/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.2435 - acc: 0.9702 - val_loss: 0.4104 - val_acc: 0.9258
#
# Epoch 00099: val_acc improved from 0.92380 to 0.92580, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 100/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.2367 - acc: 0.9719 - val_loss: 0.4114 - val_acc: 0.9245
#
# Epoch 00100: val_acc did not improve from 0.92580
# Epoch 101/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.2361 - acc: 0.9716 - val_loss: 0.4147 - val_acc: 0.9220
#
# Epoch 00101: val_acc did not improve from 0.92580
# Epoch 102/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.2323 - acc: 0.9720 - val_loss: 0.4140 - val_acc: 0.9223
#
# Epoch 00102: val_acc did not improve from 0.92580
# Epoch 103/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.2284 - acc: 0.9728 - val_loss: 0.4178 - val_acc: 0.9227
#
# Epoch 00103: val_acc did not improve from 0.92580
# Epoch 104/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.2227 - acc: 0.9745 - val_loss: 0.4307 - val_acc: 0.9206
#
# Epoch 00104: val_acc did not improve from 0.92580
# Epoch 105/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.2237 - acc: 0.9737 - val_loss: 0.4109 - val_acc: 0.9238
#
# Epoch 00105: val_acc did not improve from 0.92580
# Epoch 106/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.2218 - acc: 0.9739 - val_loss: 0.4183 - val_acc: 0.9195
#
# Epoch 00106: val_acc did not improve from 0.92580
# Epoch 107/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.2176 - acc: 0.9755 - val_loss: 0.4173 - val_acc: 0.9212
#
# Epoch 00107: val_acc did not improve from 0.92580
# Epoch 108/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.2153 - acc: 0.9756 - val_loss: 0.4189 - val_acc: 0.9239
#
# Epoch 00108: val_acc did not improve from 0.92580
# Epoch 109/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.2155 - acc: 0.9749 - val_loss: 0.4066 - val_acc: 0.9241
#
# Epoch 00109: val_acc did not improve from 0.92580
# Epoch 110/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.2102 - acc: 0.9766 - val_loss: 0.4212 - val_acc: 0.9227
#
# Epoch 00110: val_acc did not improve from 0.92580
# Epoch 111/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.2062 - acc: 0.9782 - val_loss: 0.4099 - val_acc: 0.9224
#
# Epoch 00111: val_acc did not improve from 0.92580
# Epoch 112/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 181s 116ms/step - loss: 0.2068 - acc: 0.9766 - val_loss: 0.4195 - val_acc: 0.9236
#
# Epoch 00112: val_acc did not improve from 0.92580
# Epoch 113/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.2031 - acc: 0.9781 - val_loss: 0.4149 - val_acc: 0.9221
#
# Epoch 00113: val_acc did not improve from 0.92580
# Epoch 114/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.2017 - acc: 0.9776 - val_loss: 0.4383 - val_acc: 0.9175
#
# Epoch 00114: val_acc did not improve from 0.92580
# Epoch 115/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.2011 - acc: 0.9775 - val_loss: 0.4236 - val_acc: 0.9218
#
# Epoch 00115: val_acc did not improve from 0.92580
# Epoch 116/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.1980 - acc: 0.9782 - val_loss: 0.4250 - val_acc: 0.9221
#
# Epoch 00116: val_acc did not improve from 0.92580
# Epoch 117/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.1956 - acc: 0.9789 - val_loss: 0.4129 - val_acc: 0.9252
#
# Epoch 00117: val_acc did not improve from 0.92580
# Epoch 118/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.1967 - acc: 0.9781 - val_loss: 0.4204 - val_acc: 0.9226
#
# Epoch 00118: val_acc did not improve from 0.92580
# Epoch 119/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.1926 - acc: 0.9792 - val_loss: 0.4195 - val_acc: 0.9233
#
# Epoch 00119: val_acc did not improve from 0.92580
# Epoch 120/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.1918 - acc: 0.9790 - val_loss: 0.4200 - val_acc: 0.9215
#
# Epoch 00120: val_acc did not improve from 0.92580
# Epoch 121/150
# Learning rate:  0.0001
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.1904 - acc: 0.9794 - val_loss: 0.4128 - val_acc: 0.9210
#
# Epoch 00121: val_acc did not improve from 0.92580
# Epoch 122/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.1836 - acc: 0.9824 - val_loss: 0.4028 - val_acc: 0.9242
#
# Epoch 00122: val_acc did not improve from 0.92580
# Epoch 123/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.1781 - acc: 0.9840 - val_loss: 0.3989 - val_acc: 0.9257
#
# Epoch 00123: val_acc did not improve from 0.92580
# Epoch 124/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.1777 - acc: 0.9841 - val_loss: 0.4007 - val_acc: 0.9249
#
# Epoch 00124: val_acc did not improve from 0.92580
# Epoch 125/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.1756 - acc: 0.9842 - val_loss: 0.4003 - val_acc: 0.9255
#
# Epoch 00125: val_acc did not improve from 0.92580
# Epoch 126/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.1747 - acc: 0.9848 - val_loss: 0.3998 - val_acc: 0.9266
#
# Epoch 00126: val_acc improved from 0.92580 to 0.92660, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 127/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.1749 - acc: 0.9853 - val_loss: 0.4015 - val_acc: 0.9263
#
# Epoch 00127: val_acc did not improve from 0.92660
# Epoch 128/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.1744 - acc: 0.9856 - val_loss: 0.4034 - val_acc: 0.9265
#
# Epoch 00128: val_acc did not improve from 0.92660
# Epoch 129/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.1739 - acc: 0.9853 - val_loss: 0.3992 - val_acc: 0.9271
#
# Epoch 00129: val_acc improved from 0.92660 to 0.92710, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 130/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.1732 - acc: 0.9850 - val_loss: 0.3995 - val_acc: 0.9272
#
# Epoch 00130: val_acc improved from 0.92710 to 0.92720, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 131/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.1713 - acc: 0.9858 - val_loss: 0.4002 - val_acc: 0.9274
#
# Epoch 00131: val_acc improved from 0.92720 to 0.92740, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 132/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 180s 115ms/step - loss: 0.1727 - acc: 0.9849 - val_loss: 0.4012 - val_acc: 0.9278
#
# Epoch 00132: val_acc improved from 0.92740 to 0.92780, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 133/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 178s 114ms/step - loss: 0.1722 - acc: 0.9859 - val_loss: 0.3994 - val_acc: 0.9278
#
# Epoch 00133: val_acc did not improve from 0.92780
# Epoch 134/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 182s 116ms/step - loss: 0.1706 - acc: 0.9862 - val_loss: 0.4029 - val_acc: 0.9269
#
# Epoch 00134: val_acc did not improve from 0.92780
# Epoch 135/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 182s 117ms/step - loss: 0.1682 - acc: 0.9869 - val_loss: 0.4008 - val_acc: 0.9274
#
# Epoch 00135: val_acc did not improve from 0.92780
# Epoch 136/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.1674 - acc: 0.9868 - val_loss: 0.4021 - val_acc: 0.9267
#
# Epoch 00136: val_acc did not improve from 0.92780
# Epoch 137/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.1680 - acc: 0.9871 - val_loss: 0.4041 - val_acc: 0.9264
#
# Epoch 00137: val_acc did not improve from 0.92780
# Epoch 138/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 179s 115ms/step - loss: 0.1676 - acc: 0.9866 - val_loss: 0.4033 - val_acc: 0.9260
#
# Epoch 00138: val_acc did not improve from 0.92780
# Epoch 139/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 180s 115ms/step - loss: 0.1688 - acc: 0.9865 - val_loss: 0.4072 - val_acc: 0.9266
#
# Epoch 00139: val_acc did not improve from 0.92780
# Epoch 140/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 181s 116ms/step - loss: 0.1679 - acc: 0.9868 - val_loss: 0.4023 - val_acc: 0.9270
#
# Epoch 00140: val_acc did not improve from 0.92780
# Epoch 141/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 178s 114ms/step - loss: 0.1688 - acc: 0.9858 - val_loss: 0.4021 - val_acc: 0.9269
#
# Epoch 00141: val_acc did not improve from 0.92780
# Epoch 142/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 180s 115ms/step - loss: 0.1652 - acc: 0.9878 - val_loss: 0.4027 - val_acc: 0.9277
#
# Epoch 00142: val_acc did not improve from 0.92780
# Epoch 143/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 182s 116ms/step - loss: 0.1654 - acc: 0.9879 - val_loss: 0.4069 - val_acc: 0.9270
#
# Epoch 00143: val_acc did not improve from 0.92780
# Epoch 144/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.1672 - acc: 0.9867 - val_loss: 0.4060 - val_acc: 0.9271
#
# Epoch 00144: val_acc did not improve from 0.92780
# Epoch 145/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.1663 - acc: 0.9867 - val_loss: 0.4048 - val_acc: 0.9275
#
# Epoch 00145: val_acc did not improve from 0.92780
# Epoch 146/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.1664 - acc: 0.9868 - val_loss: 0.4063 - val_acc: 0.9279
#
# Epoch 00146: val_acc improved from 0.92780 to 0.92790, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 147/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 185s 118ms/step - loss: 0.1665 - acc: 0.9868 - val_loss: 0.4047 - val_acc: 0.9277
#
# Epoch 00147: val_acc did not improve from 0.92790
# Epoch 148/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 184s 118ms/step - loss: 0.1653 - acc: 0.9870 - val_loss: 0.4024 - val_acc: 0.9286
#
# Epoch 00148: val_acc improved from 0.92790 to 0.92860, saving model to ../models/weights/CIFAR10_ResNet110v2.keras_weights.h5
# Epoch 149/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.1652 - acc: 0.9873 - val_loss: 0.4042 - val_acc: 0.9282
#
# Epoch 00149: val_acc did not improve from 0.92860
# Epoch 150/150
# Learning rate:  1e-05
# 1562/1562 [==============================] - 183s 117ms/step - loss: 0.1635 - acc: 0.9878 - val_loss: 0.4041 - val_acc: 0.9285
#
# Epoch 00150: val_acc did not improve from 0.92860

# %%
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
